# %%
from io import IncrementalNewlineDecoder
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
filepath = '/content/Cab Service Feedback Survey (Responses) - Google Sheets.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-4-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
data = pd.read_csv(filepath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d0edcf0ef274> in <cell line: 1>()
# ----> 1 data = pd.read_csv(filepath)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# QUESTION STAR FROM HERE ONWARDS

# %% [markdown]
# #  Number of users of the service?

# %%
#Number of users of the service?
num_users = data['You use'].value_counts()
print("Number of users of the service:", num_users)
plt.figure(figsize=(13, 4))
num_users.plot(kind='bar', color=['blue', 'green'])
plt.title('Number of Users of the Service')
plt.xlabel('Usage of the Service')
plt.ylabel('Number of Users')
plt.xticks(rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-94d2cb65bedc> in <cell line: 2>()
#       1 #Number of users of the service?
# ----> 2 num_users = data['You use'].value_counts()
#       3 print("Number of users of the service:", num_users)
#       4 plt.figure(figsize=(13, 4))
#       5 num_users.plot(kind='bar', color=['blue', 'green'])
#
# NameError: name 'data' is not defined

# %% [markdown]
# # What is the gender distribution among the respondents?

# %%
gender_distribution = data['Gender'].value_counts()
print("Gender distribution:\n", gender_distribution)
plt.figure(figsize=(8, 6))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct='%1.1f%%', startangle=140,
        colors=['lightblue', 'lightgreen'])
plt.title('Gender Distribution of Respondents')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# Gender distribution:
#  Gender
# Male      82
# Female    66
# Name: count, dtype: int64

# %% [markdown]
# # What are the influencing factors reported by the users?

# %%
influencing_factors = data['Influencing factors'].str.split(', ').explode().value_counts()
print("Influencing factors reported by users:\n", influencing_factors)
plt.figure(figsize=(10, 6))
influencing_factors.plot(kind='bar', color='lightgreen')
plt.title('Influencing Factors Reported by Users')
plt.xlabel('Factors')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.show()
# Out:
# Influencing factors reported by users:
#  Influencing factors
# Availability                 86
# Price                        64
# Safety measures              38
# Wait time                    28
# Service quality              23
# Vehicles                     22
# Discounts                    17
# Saf                           1
# Safety measures,              1
# Safety measures,Discounts     1
# Price,Wait time               1
# Name: count, dtype: int64

# %% [markdown]
# # How many entries are there in the dataset?

# %%
# 1. Number of entries in the dataset
num_entries = len(data)
print("Number of entries in the dataset:", num_entries)
plt.figure(figsize=(6, 4))
plt.bar("Entries", num_entries, color='skyblue')
plt.title('Number of Entries in the Dataset')
plt.xlabel('Dataset')
plt.ylabel('Number of Entries')
plt.grid(axis='y')
plt.show()
# Out:
# Number of entries in the dataset: 148

# %% [markdown]
# # What percentage of users would recommend the service?

# %%
# 6. Percentage of users recommending the service
recommend_percentage = (data['Would you recommend'].value_counts()['Yes'] / num_entries) * 100
print("Percentage of users recommending the service:", recommend_percentage)
plt.figure(figsize=(8, 6))
plt.pie([recommend_percentage, 100 - recommend_percentage], labels=['Yes', 'No'], autopct='%1.1f%%', startangle=140, colors=['lightgreen', 'lightcoral'])
plt.title('Percentage of Users Recommending the Service')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# Percentage of users recommending the service: 67.56756756756756

# %% [markdown]
# # How satisfied are users with the time aspect of the service?

# %%
# 7. Satisfaction level with the time aspect of the service
time_satisfaction = data['Time'].value_counts()
print("Satisfaction level with the time aspect of the service:\n", time_satisfaction)
plt.figure(figsize=(8, 6))
time_satisfaction.plot(kind='bar', color='skyblue')
plt.title('Satisfaction Level with the Time Aspect of the Service')
plt.xlabel('Satisfaction Level')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()
# Out:
# Satisfaction level with the time aspect of the service:
#  Time
# Morning / Afternoon    62
# Evening                54
# Afternoon              17
# After dark             15
# Name: count, dtype: int64

# %% [markdown]
# # What is the satisfaction level regarding on-time pickup and drop-off?

# %%
# 9. Satisfaction level regarding on-time pickup and drop-off
on_time_satisfaction = data['On-time Pickup and Drop'].value_counts()
print("Satisfaction level regarding on-time pickup and drop-off:\n", on_time_satisfaction)
plt.figure(figsize=(8, 6))
on_time_satisfaction.plot(kind='bar', color='lightgreen')
plt.title('Satisfaction Level Regarding On-time Pickup and Drop-off')
plt.xlabel('Satisfaction Level')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()
# Out:
# Satisfaction level regarding on-time pickup and drop-off:
#  On-time Pickup and Drop
# Rapido    67
# Uber      41
# Ola       40
# Name: count, dtype: int64

# %% [markdown]
# # How many respondents provided a reason for not using the service?

# %%
# 10. Number of respondents providing a reason for not using the service
reasons_provided = data['Reason for not using'].notna().sum()
print("Number of respondents providing a reason for not using the service:", reasons_provided)
plt.figure(figsize=(6, 4))
plt.bar("Reasons Provided", reasons_provided, color='salmon')
plt.title('Number of Respondents Providing a Reason for Not Using the Service')
plt.xlabel('Reasons Provided')
plt.ylabel('Number of Respondents')
plt.grid(axis='y')
plt.show()
# Out:
# Number of respondents providing a reason for not using the service: 145

# %% [markdown]
# # How does satisfaction with the time aspect of the service vary among users who would recommend it versus those who wouldn't?

# %%
# 20. Satisfaction level with the time aspect of the service among users who would recommend it versus those who wouldn't
recommend_time_satisfaction = data.groupby('Would you recommend')['Time'].value_counts()
print("Satisfaction level with the time aspect of the service among users who would recommend it versus those who wouldn't:\n", recommend_time_satisfaction)
recommend_time_satisfaction.plot(kind='bar', figsize=(25, 6), color=['skyblue', 'salmon'])
plt.title('Satisfaction Level with the Time Aspect of the Service by Recommendation')
plt.xlabel('Recommendation')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.legend(title='Time')
plt.grid(axis='y')
plt.show()
# Out:
# Satisfaction level with the time aspect of the service among users who would recommend it versus those who wouldn't:
#  Would you recommend  Time
# Maybe                Morning / Afternoon    16
#                      Evening                11
#                      After dark              8
#                      Afternoon               6
# No                   Morning / Afternoon     3
#                      Evening                 2
#                      After dark              1
#                      Afternoon               1
# Yes                  Morning / Afternoon    43
#                      Evening                41
#                      Afternoon              10
#                      After dark              6
# Name: count, dtype: int64
